# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/Users/bunarisaisumanth/Downloads/customer_purchase_data.csv")

# %%
print(data)
# Out:
#       Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0      40       1   66120.267939                  8                0
# 1      20       1   23579.773583                  4                2
# 2      27       1  127821.306432                 11                2
# 3      24       1  137798.623120                 19                3
# 4      31       1   99300.964220                 19                1
# ...   ...     ...            ...                ...              ...
# 1495   39       1   65048.141834                 13                0
# 1496   67       1   28775.331069                 18                2
# 1497   40       1   57363.247541                  7                4
# 1498   63       0  134021.775532                 16                2
# 1499   50       0   52625.665974                 13                0
#
#       TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 1500 non-null   int64
#  1   Gender              1500 non-null   int64
#  2   AnnualIncome        1500 non-null   float64
#  3   NumberOfPurchases   1500 non-null   int64
#  4   ProductCategory     1500 non-null   int64
#  5   TimeSpentOnWebsite  1500 non-null   float64
#  6   LoyaltyProgram      1500 non-null   int64
#  7   DiscountsAvailed    1500 non-null   int64
#  8   PurchaseStatus      1500 non-null   int64
# dtypes: float64(2), int64(7)
# memory usage: 105.6 KB

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'AnnualIncome', 'NumberOfPurchases', 'ProductCategory',
#        'TimeSpentOnWebsite', 'LoyaltyProgram', 'DiscountsAvailed',
#        'PurchaseStatus'],
#       dtype='object')

# %%
list(data.columns)
# Out:
# ['Age',
#  'Gender',
#  'AnnualIncome',
#  'NumberOfPurchases',
#  'ProductCategory',
#  'TimeSpentOnWebsite',
#  'LoyaltyProgram',
#  'DiscountsAvailed',
#  'PurchaseStatus']

# %%
np.linspace(120,140)
# Out:
# array([120.        , 120.40816327, 120.81632653, 121.2244898 ,
#        121.63265306, 122.04081633, 122.44897959, 122.85714286,
#        123.26530612, 123.67346939, 124.08163265, 124.48979592,
#        124.89795918, 125.30612245, 125.71428571, 126.12244898,
#        126.53061224, 126.93877551, 127.34693878, 127.75510204,
#        128.16326531, 128.57142857, 128.97959184, 129.3877551 ,
#        129.79591837, 130.20408163, 130.6122449 , 131.02040816,
#        131.42857143, 131.83673469, 132.24489796, 132.65306122,
#        133.06122449, 133.46938776, 133.87755102, 134.28571429,
#        134.69387755, 135.10204082, 135.51020408, 135.91836735,
#        136.32653061, 136.73469388, 137.14285714, 137.55102041,
#        137.95918367, 138.36734694, 138.7755102 , 139.18367347,
#        139.59183673, 140.        ])

# %%
array = np.random.rand(3,4)
print(array)
# Out:
# [[0.9639585  0.43598081 0.21038031 0.99855088]
#  [0.22125388 0.74884654 0.40954107 0.86325418]
#  [0.67873237 0.16598826 0.07384299 0.23772813]]

# %%
np.random.rand(100)
# Out:
# array([0.8654041 , 0.74628837, 0.13043803, 0.47985887, 0.45995436,
#        0.00873656, 0.47314471, 0.56902532, 0.92789678, 0.52143027,
#        0.20924131, 0.62267737, 0.34162713, 0.85498083, 0.87241363,
#        0.8969114 , 0.55470537, 0.33453449, 0.98840973, 0.67977979,
#        0.86376743, 0.38589252, 0.05965597, 0.92778611, 0.1367933 ,
#        0.79001182, 0.95729475, 0.84184714, 0.73978737, 0.25867988,
#        0.45130076, 0.54383359, 0.66795182, 0.80897743, 0.36106607,
#        0.69248538, 0.27297126, 0.53349433, 0.06105168, 0.74419069,
#        0.15528549, 0.53111462, 0.15308815, 0.76016525, 0.26956533,
#        0.95814711, 0.04630246, 0.13319659, 0.50265124, 0.80861539,
#        0.10885153, 0.01462474, 0.48270537, 0.39923467, 0.61753532,
#        0.40029735, 0.5458126 , 0.05940041, 0.65274142, 0.17904067,
#        0.13551003, 0.68251431, 0.41637255, 0.85367766, 0.60530987,
#        0.61279738, 0.10747254, 0.13670383, 0.58477121, 0.46824546,
# ...

# %%
print(np.sum(array, axis = 0))
# Out:
# [1.86394475 1.35081561 0.69376437 2.09953319]

# %%
print(np.sum(array, axis = 1))
# Out:
# [2.60887049 2.24289567 1.15629175]

# %%
print(np.sort(array, axis = 1))
# Out:
# [[0.21038031 0.43598081 0.9639585  0.99855088]
#  [0.22125388 0.40954107 0.74884654 0.86325418]
#  [0.07384299 0.16598826 0.23772813 0.67873237]]

# %%
print(np.mean(array))
print(np.median(array))
# Out:
# 0.5006714930368702
# 0.42276093907968804

# %%
data.head()
# Out:
#    Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0   40       1   66120.267939                  8                0
# 1   20       1   23579.773583                  4                2
# 2   27       1  127821.306432                 11                2
# 3   24       1  137798.623120                 19                3
# 4   31       1   99300.964220                 19                1
#
#    TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 0           30.568601               0                 5               1
# 1           38.240097               0                 5               0
# 2           31.633212               1                 0               1
# 3           46.167059               0                 4               1
# 4           19.823592               0                 0               1

# %%
data.tail()
# Out:
#       Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 1495   39       1   65048.141834                 13                0
# 1496   67       1   28775.331069                 18                2
# 1497   40       1   57363.247541                  7                4
# 1498   63       0  134021.775532                 16                2
# 1499   50       0   52625.665974                 13                0
#
#       TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 1495           34.590743               0                 5               1
# 1496           17.625707               0                 1               1
# 1497           12.206033               0                 0               0
# 1498           37.311634               1                 0               1
# 1499           25.348017               1                 4               1

# %%
print(data.shape)
print(data.shape[0])
print(data.shape[1])
# Out:
# (1500, 9)
# 1500
# 9

# %%
data.describe()
# Out:
#                Age       Gender   AnnualIncome  NumberOfPurchases  \
# count  1500.000000  1500.000000    1500.000000        1500.000000
# mean     44.298667     0.504667   84249.164338          10.420000
# std      15.537259     0.500145   37629.493078           5.887391
# min      18.000000     0.000000   20001.512518           0.000000
# 25%      31.000000     0.000000   53028.979155           5.000000
# 50%      45.000000     1.000000   83699.581476          11.000000
# 75%      57.000000     1.000000  117167.772858          15.000000
# max      70.000000     1.000000  149785.176481          20.000000
#
#        ProductCategory  TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  \
# count      1500.000000         1500.000000     1500.000000       1500.000000
# mean          2.012667           30.469040        0.326667          2.555333
# std           1.428005           16.984392        0.469151          1.705152
# ...

# %%
data.isnull().sum()
# Out:
# Age                   0
# Gender                0
# AnnualIncome          0
# NumberOfPurchases     0
# ProductCategory       0
# TimeSpentOnWebsite    0
# LoyaltyProgram        0
# DiscountsAvailed      0
# PurchaseStatus        0
# dtype: int64

# %%
data.isna().any()
# Out:
# Age                   False
# Gender                False
# AnnualIncome          False
# NumberOfPurchases     False
# ProductCategory       False
# TimeSpentOnWebsite    False
# LoyaltyProgram        False
# DiscountsAvailed      False
# PurchaseStatus        False
# dtype: bool

# %%
data.isnull().head(10)
# Out:
#      Age  Gender  AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0  False   False         False              False            False
# 1  False   False         False              False            False
# 2  False   False         False              False            False
# 3  False   False         False              False            False
# 4  False   False         False              False            False
# 5  False   False         False              False            False
# 6  False   False         False              False            False
# 7  False   False         False              False            False
# 8  False   False         False              False            False
# 9  False   False         False              False            False
#
#    TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 0               False           False             False           False
# 1               False           False             False           False
# ...

# %%
data.isnull().tail(10)
# Out:
#         Age  Gender  AnnualIncome  NumberOfPurchases  ProductCategory  \
# 1490  False   False         False              False            False
# 1491  False   False         False              False            False
# 1492  False   False         False              False            False
# 1493  False   False         False              False            False
# 1494  False   False         False              False            False
# 1495  False   False         False              False            False
# 1496  False   False         False              False            False
# 1497  False   False         False              False            False
# 1498  False   False         False              False            False
# 1499  False   False         False              False            False
#
#       TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 1490               False           False             False           False
# ...

# %%
data.loc[1278]
# Out:
# Age                       31.000000
# Gender                     0.000000
# AnnualIncome          128612.429346
# NumberOfPurchases         12.000000
# ProductCategory            3.000000
# TimeSpentOnWebsite        33.436109
# LoyaltyProgram             0.000000
# DiscountsAvailed           2.000000
# PurchaseStatus             1.000000
# Name: 1278, dtype: float64

# %%
data.iloc[909]
# Out:
# Age                      27.000000
# Gender                    0.000000
# AnnualIncome          33327.075329
# NumberOfPurchases         5.000000
# ProductCategory           3.000000
# TimeSpentOnWebsite       22.436032
# LoyaltyProgram            0.000000
# DiscountsAvailed          5.000000
# PurchaseStatus            0.000000
# Name: 909, dtype: float64

# %%
data.loc[245:258]
# Out:
#      Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 245   70       0  126922.473272                 12                2
# 246   43       0   89293.752742                 10                4
# 247   70       0  123568.581635                  5                3
# 248   18       1   24995.425365                 15                3
# 249   59       1   86588.849706                  6                1
# 250   38       0  144269.447764                 17                1
# 251   68       0  134789.197228                  3                0
# 252   65       0   65922.683105                 15                3
# 253   50       0  113878.620609                 15                0
# 254   22       0   29992.069786                  1                1
# 255   48       1  130295.299282                 19                3
# 256   52       0   46909.035197                  7                0
# 257   65       0  100913.773404                 17                1
# ...

# %%
data[data.index.isin(range(120,140))]
# Out:
#      Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 120   57       1  112561.822643                  8                0
# 121   64       1  132261.177927                 13                3
# 122   43       0   45897.985736                  1                4
# 123   41       0   70461.541797                 11                2
# 124   65       1   26529.381490                 18                3
# 125   68       1   30007.330718                 19                3
# 126   19       1   24590.476142                  1                3
# 127   38       0  115929.261136                 20                3
# 128   53       1   30017.576287                 14                3
# 129   64       0  112523.964747                  9                4
# 130   70       1   86224.876659                 13                0
# 131   21       1   36652.447028                 16                4
# 132   58       1  143569.036836                 20                1
# ...

# %%
data[['Age', 'Gender']].tail(10)
# Out:
#       Age  Gender
# 1490   18       1
# 1491   30       0
# 1492   63       0
# 1493   34       1
# 1494   34       1
# 1495   39       1
# 1496   67       1
# 1497   40       1
# 1498   63       0
# 1499   50       0

# %%
data[['Age', 'Gender']].head(10)
# Out:
#    Age  Gender
# 0   40       1
# 1   20       1
# 2   27       1
# 3   24       1
# 4   31       1
# 5   66       1
# 6   39       1
# 7   64       1
# 8   43       0
# 9   20       1

# %%
data['Age'].tail(10)
# Out:
# 1490    18
# 1491    30
# 1492    63
# 1493    34
# 1494    34
# 1495    39
# 1496    67
# 1497    40
# 1498    63
# 1499    50
# Name: Age, dtype: int64

# %%
data['Age'].value_counts()
# Out:
# Age
# 68    43
# 50    42
# 66    40
# 64    40
# 45    38
# 22    37
# 18    34
# 43    34
# 25    34
# 40    33
# 41    33
# 52    33
# 69    33
# 54    33
# 19    32
# 49    31
# 61    30
# 46    30
# 57    30
# 70    30
# 20    30
# 42    29
# 56    29
# 47    29
# 39    29
# 62    28
# 31    27
# 53    27
# 29    27
# 23    27
# 28    27
# 65    26
# 38    26
# 36    26
# 26    26
# 34    25
# 37    25
# 21    25
# 27    24
# 55    24
# 58    23
# 51    23
# 32    23
# 30    23
# 33    22
# 44    22
# 24    22
# 35    21
# 48    20
# 60    20
# 63    19
# 67    19
# 59    17
# Name: count, dtype: int64

# %%
b = data[np.full((6), 'Age')].tail(10)
print(b)
# Out:
#       Age  Age  Age  Age  Age  Age
# 1490   18   18   18   18   18   18
# 1491   30   30   30   30   30   30
# 1492   63   63   63   63   63   63
# 1493   34   34   34   34   34   34
# 1494   34   34   34   34   34   34
# 1495   39   39   39   39   39   39
# 1496   67   67   67   67   67   67
# 1497   40   40   40   40   40   40
# 1498   63   63   63   63   63   63
# 1499   50   50   50   50   50   50

# %%
dt = data.head(33)
dt.sort_index(ascending = True).tail(10)
# Out:
#     Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 23   22       1   56597.755794                 16                4
# 24   31       0   78117.220695                 13                0
# 25   62       0  108227.094367                 18                3
# 26   67       1  102252.544237                 14                1
# 27   66       0   97875.796330                 17                1
# 28   67       1   23792.069274                 15                4
# 29   48       1  138727.303185                  9                0
# 30   52       1   42589.007108                  1                1
# 31   63       0   80023.098696                 11                2
# 32   36       0  144947.613103                 12                1
#
#     TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 23           14.827835               1                 1               1
# 24           30.353469               0                 1               1
# ...

# %%
dt = data.head()
dt.sort_index(ascending = False).head()
# Out:
#    Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 4   31       1   99300.964220                 19                1
# 3   24       1  137798.623120                 19                3
# 2   27       1  127821.306432                 11                2
# 1   20       1   23579.773583                  4                2
# 0   40       1   66120.267939                  8                0
#
#    TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 4           19.823592               0                 0               1
# 3           46.167059               0                 4               1
# 2           31.633212               1                 0               1
# 1           38.240097               0                 5               0
# 0           30.568601               0                 5               1

# %%
dt = data[data.index.isin(range(0,10))]
dt_sort = dt.sort_values(by = "Age")
print(dt_sort)
# Out:
#    Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 1   20       1   23579.773583                  4                2
# 9   20       1   63854.921080                 16                0
# 3   24       1  137798.623120                 19                3
# 2   27       1  127821.306432                 11                2
# 4   31       1   99300.964220                 19                1
# 6   39       1  126883.385286                 16                3
# 0   40       1   66120.267939                  8                0
# 8   43       0  102797.301269                 20                1
# 7   64       1   39707.359724                 13                2
# 5   66       1   37758.117475                 14                4
#
#    TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 1           38.240097               0                 5               0
# 9           38.572466               0                 5               1
# ...

# %%
data['ProductCategory'].head(10) >= 3
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# 6     True
# 7    False
# 8    False
# 9    False
# Name: ProductCategory, dtype: bool

# %%
d = data['Age']
a = 0
for i in d:
    if i <= 40:
        a += 1
print(c)
# Out:
# 625

# %%
dt = data[data.index.isin(range(234, 260))]
dt1 = dt.loc[dt['Age'] <= 70]
sns.barplot(data = dt1 , x = 'Age', y = 'AnnualIncome')
# Out:
# <Axes: xlabel='Age', ylabel='AnnualIncome'>

# %%
dt = data[data.index.isin(range(234, 260))]
dt1 = dt.loc[dt['Age'] <= 70]
sns.lineplot(data = dt1 , x = 'Age', y = 'AnnualIncome')
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Age', ylabel='AnnualIncome'>

# %%
dt = data[data.index.isin(range(210,222))]
sns.countplot(y='TimeSpentOnWebsite', data = dt)
# Out:
# <Axes: xlabel='count', ylabel='TimeSpentOnWebsite'>

# %%
data.head(25)
dt1 = dt[dt['Age'] > 18]
sns.stripplot(x = 'NumberOfPurchases', y = 'Age', data = dt1)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='NumberOfPurchases', ylabel='Age'>

# %%
data.head(25)
dt2 = data[(data['Age'] > 41)&(data['AnnualIncome'] >= 141720.58)]
sns.stripplot(x = 'Age', y = 'AnnualIncome', data = dt2)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Age', ylabel='AnnualIncome'>

# %%
dt=data.head(11)
sns.pairplot(data[['Age','AnnualIncome','NumberOfPurchases']])
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
data = data.head(20)
sns.displot(data['AnnualIncome'])
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
dt = data[data.index.isin(range(0,10))]
sns.histplot(data = dt, x = "Age", kde = True)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Age', ylabel='Count'>

# %%
dt = data[data.index.isin(range(0,70))]
rs = np.random.RandomState(11)
x = rs.gamma(2, size=1000)
y = -.5 * x + rs.normal(size=1000)
sns.jointplot(data = dt, x = "Age", y = "AnnualIncome", kind = "hex", color="#4CB391")
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
dt = data[data.index.isin(range(100,120))]
sns.boxplot(x = "Age", y = "AnnualIncome", data = dt)
# Out:
# <Axes: xlabel='Age', ylabel='AnnualIncome'>

# %%
data.count()
# Out:
# Age                   1500
# Gender                1500
# AnnualIncome          1500
# NumberOfPurchases     1500
# ProductCategory       1500
# TimeSpentOnWebsite    1500
# LoyaltyProgram        1500
# DiscountsAvailed      1500
# PurchaseStatus        1500
# dtype: int64

# %%
duplicate_rows_data = data[data.duplicated()]
print("Number of duplicate rows:", duplicate_rows_data.shape)
# Out:
# Number of duplicate rows: (112, 9)

# %%
data = data.drop_duplicates()
data.head(10)
# Out:
#    Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0   40       1   66120.267939                  8                0
# 1   20       1   23579.773583                  4                2
# 2   27       1  127821.306432                 11                2
# 3   24       1  137798.623120                 19                3
# 4   31       1   99300.964220                 19                1
# 5   66       1   37758.117475                 14                4
# 6   39       1  126883.385286                 16                3
# 7   64       1   39707.359724                 13                2
# 8   43       0  102797.301269                 20                1
# 9   20       1   63854.921080                 16                0
#
#    TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 0           30.568601               0                 5               1
# 1           38.240097               0                 5               0
# ...

# %%
data[['Age', 'AnnualIncome', 'NumberOfPurchases']].corr()
sns.heatmap(data[['Age', 'AnnualIncome', 'NumberOfPurchases']].corr(), annot = True, cmap = 'Reds')
plt.show()

# %%
data.hist(figsize = (10, 10))
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Gender'}>,
#         <Axes: title={'center': 'AnnualIncome'}>],
#        [<Axes: title={'center': 'NumberOfPurchases'}>,
#         <Axes: title={'center': 'ProductCategory'}>,
#         <Axes: title={'center': 'TimeSpentOnWebsite'}>],
#        [<Axes: title={'center': 'LoyaltyProgram'}>,
#         <Axes: title={'center': 'DiscountsAvailed'}>,
#         <Axes: title={'center': 'PurchaseStatus'}>]], dtype=object)

# %%
sns.pairplot(data, hue = 'NumberOfPurchases')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
plt. figure (figsize=(10,10))
a = data.corr()
sns.heatmap(a, cmap = "BrBG", annot = True)
# Out:
# <Axes: >
